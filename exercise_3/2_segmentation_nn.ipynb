# %% [markdown]
# Semantic Segmentation
# ============
#
# In this exercise you are going to work on a computer vision task called semantic segmentation. In comparison to image classification the goal is not to classify an entire image but each of its pixels separately. This implies that the  output of the network is not a single scalar but a segmentation with the same shape as the input image. Think about why you should rather use convolutional than fully-connected layers for this task!
#
# Since we already introduced the basics of PyTorch and how to train a NN we leave the model design and architecture as well as the training up to you. We only provide you with the train, validation and test dataset and recommend you to look for inspirational, existing PyTorch implementations. Due to the fairly small size of the segmentation dataset you should not train a model from scratch but consider to (at least partially) finetune weights of an already exsisting model.
#
# The infamous  [Fully Convolutional Networks for Semantic Segmentation](https://people.eecs.berkeley.edu/~jonlong/long_shelhamer_fcn.pdf) paper might help you with finding a suitable segmentation model and architecture.
#
# <img src="https://camo.githubusercontent.com/d10b897e15344334e449104a824aff6c29125dc2/687474703a2f2f63616c76696e2e696e662e65642e61632e756b2f77702d636f6e74656e742f75706c6f6164732f646174612f636f636f7374756666646174617365742f636f636f73747566662d6578616d706c65732e706e67">

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

from exercise_code.data_utils import SegmentationData, label_img_to_rgb

#torch.set_default_tensor_type('torch.FloatTensor')
#set up default cuda device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# MSRC-v2 Segmentation Dataset
# ================
#
# Make yourself familiar with the segmentation dataset and how we implemented the `SegmentationData` class in `exercise_code/data_utils.py`. Furthermore have a look at the labels described in `data/segmentation_data/info.html`. Especially note the label `unlabeled`. Pixels with the label `unlabeled` should neither be considered in your loss nor in the accuracy of your segmentation.

# %%
train_data = SegmentationData(image_paths_file='datasets/segmentation_data/train.txt')
val_data = SegmentationData(image_paths_file='datasets/segmentation_data/val.txt')

# %%
print("Train size: %i" % len(train_data))
print("Validation size: %i" % len(val_data))
print("Img size: ", train_data[0][0].size())
print("Segmentation size: ", train_data[0][1].size())

num_example_imgs = 3
plt.figure(figsize=(10, 5 * num_example_imgs))
for i, (img, target) in enumerate(train_data[:num_example_imgs]):
    # img
    plt.subplot(num_example_imgs, 2, i * 2 + 1)
    plt.imshow(img.numpy().transpose(1,2,0))
    plt.axis('off')
    if i == 0:
        plt.title("Input image")
    
    # target
    plt.subplot(num_example_imgs, 2, i * 2 + 2)
    plt.imshow(label_img_to_rgb(target.numpy()))
    plt.axis('off')
    if i == 0:
        plt.title("Target image")
plt.show()
# Out:
# Train size: 276
# Validation size: 59
# Img size:  torch.Size([3, 240, 240])
# Segmentation size:  torch.Size([240, 240])

# %% [markdown]
# Design and Train your Network
# ==========
#
# Implement your network architecture in `exercise_code/classifiers/segmentation_nn.py` and adapt your `Solver` to process segmentation labels. To compensate for the dimension reduction of a typical convolution layer, you should probably include a `nn.Upsample` layer near the end of your network. Also remember to consider finetuning a model instead of training it from scratch.
#
# Up until now we only used the default loss function (`nn.CrossEntropyLoss`) of our `Solver` class. However, in order to ignore the `unlabeled` pixels for the computation of our loss, we have to use a customized version of the loss for the initializtation of the `Solver` class. The `ignore_index` argument of the loss can be used to filter the `unlabeled` pixels and computes the loss only over remaining pixels.
#
# Step by step:
# 1. Initialize training and validation data loaders.
# 2. Design and initialize a convolutional neural network architecture that has input (N, C, H, W) and output (N, num_classes, H, W) and is based on an already pretrained network.
# 3. Initialize a solver with a loss function that considers the `unlabeled` pixels.
# 4. Adjust the logging of your solver to account for the `unlabeled` pixels.
# 5. Train a segmentation model.

# %%
from exercise_code.segmentation_nn import SegmentationNN
from exercise_code.solver import Solver
import torch.nn.functional as F

train_loader = torch.utils.data.DataLoader(train_data, batch_size=5, shuffle=True, num_workers=1)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=1, shuffle=False, num_workers=1)

model = SegmentationNN()
model.to(device)
#solver = Solver(optim_args={"lr": 1e-4, "weight_decay": 0.001},
#                loss_func=torch.nn.CrossEntropyLoss(size_average=True, ignore_index=-1))


solver = Solver(optim_args={"lr": 5e-5, "weight_decay": 0.0005},
                loss_func=torch.nn.CrossEntropyLoss(size_average=True, ignore_index=-1))
solver.train(model, train_loader, val_loader, log_nth=5, num_epochs=40)
# Out:
# START TRAIN.
# [Iteration 5/2240] TRAIN loss: 3.148
# [Iteration 10/2240] TRAIN loss: 3.105
# [Iteration 15/2240] TRAIN loss: 3.024
# [Iteration 20/2240] TRAIN loss: 2.876
# [Iteration 25/2240] TRAIN loss: 2.614
# [Iteration 30/2240] TRAIN loss: 2.803
# [Iteration 35/2240] TRAIN loss: 2.642
# [Iteration 40/2240] TRAIN loss: 2.612
# [Iteration 45/2240] TRAIN loss: 2.681
# [Iteration 50/2240] TRAIN loss: 2.385
# [Iteration 55/2240] TRAIN loss: 2.481
# [Epoch 1/40] TRAIN acc/loss: 0.000/2.481
# [Epoch 1/40] VAL   acc/loss: 0.381/2.260
# [Iteration 61/2240] TRAIN loss: 1.902
# [Iteration 66/2240] TRAIN loss: 2.141
# [Iteration 71/2240] TRAIN loss: 2.048
# [Iteration 76/2240] TRAIN loss: 2.060
# [Iteration 81/2240] TRAIN loss: 1.690
# [Iteration 86/2240] TRAIN loss: 1.938
# [Iteration 91/2240] TRAIN loss: 1.947
# [Iteration 96/2240] TRAIN loss: 1.793
# [Iteration 101/2240] TRAIN loss: 1.665
# [Iteration 106/2240] TRAIN loss: 2.011
# [Iteration 111/2240] TRAIN loss: 1.731
# [Epoch 2/40] TRAIN acc/loss: 0.000/1.731
# [Epoch 2/40] VAL   acc/loss: 0.508/1.702
# [Iteration 117/2240] TRAIN loss: 1.601
# [Iteration 122/2240] TRAIN loss: 1.235
# [Iteration 127/2240] TRAIN loss: 1.587
# [Iteration 132/2240] TRAIN loss: 1.737
# [Iteration 137/2240] TRAIN loss: 1.410
# [Iteration 142/2240] TRAIN loss: 1.713
# [Iteration 147/2240] TRAIN loss: 1.316
# [Iteration 152/2240] TRAIN loss: 1.265
# [Iteration 157/2240] TRAIN loss: 1.584
# [Iteration 162/2240] TRAIN loss: 1.462
# [Iteration 167/2240] TRAIN loss: 1.231
# [Epoch 3/40] TRAIN acc/loss: 0.000/1.231
# [Epoch 3/40] VAL   acc/loss: 0.506/1.621
# [Iteration 173/2240] TRAIN loss: 1.324
# [Iteration 178/2240] TRAIN loss: 1.294
# [Iteration 183/2240] TRAIN loss: 1.268
# [Iteration 188/2240] TRAIN loss: 1.420
# [Iteration 193/2240] TRAIN loss: 1.399
# [Iteration 198/2240] TRAIN loss: 1.055
# [Iteration 203/2240] TRAIN loss: 1.207
# [Iteration 208/2240] TRAIN loss: 1.384
# [Iteration 213/2240] TRAIN loss: 1.209
# [Iteration 218/2240] TRAIN loss: 1.347
# [Iteration 223/2240] TRAIN loss: 1.216
# [Epoch 4/40] TRAIN acc/loss: 0.411/1.216
# [Epoch 4/40] VAL   acc/loss: 0.546/1.410
# [Iteration 229/2240] TRAIN loss: 1.290
# [Iteration 234/2240] TRAIN loss: 1.151
# [Iteration 239/2240] TRAIN loss: 1.262
# [Iteration 244/2240] TRAIN loss: 1.167
# [Iteration 249/2240] TRAIN loss: 1.127
# [Iteration 254/2240] TRAIN loss: 1.028
# [Iteration 259/2240] TRAIN loss: 1.304
# [Iteration 264/2240] TRAIN loss: 1.064
# [Iteration 269/2240] TRAIN loss: 1.183
# [Iteration 274/2240] TRAIN loss: 1.215
# [Iteration 279/2240] TRAIN loss: 1.046
# [Epoch 5/40] TRAIN acc/loss: 0.381/1.046
# [Epoch 5/40] VAL   acc/loss: 0.583/1.343
# [Iteration 285/2240] TRAIN loss: 1.224
# [Iteration 290/2240] TRAIN loss: 1.092
# [Iteration 295/2240] TRAIN loss: 0.926
# [Iteration 300/2240] TRAIN loss: 1.381
# [Iteration 305/2240] TRAIN loss: 1.232
# [Iteration 310/2240] TRAIN loss: 0.934
# [Iteration 315/2240] TRAIN loss: 0.994
# [Iteration 320/2240] TRAIN loss: 1.200
# [Iteration 325/2240] TRAIN loss: 1.144
# [Iteration 330/2240] TRAIN loss: 0.963
# [Iteration 335/2240] TRAIN loss: 1.151
# [Epoch 6/40] TRAIN acc/loss: 0.626/1.151
# [Epoch 6/40] VAL   acc/loss: 0.573/1.264
# [Iteration 341/2240] TRAIN loss: 1.085
# [Iteration 346/2240] TRAIN loss: 0.916
# [Iteration 351/2240] TRAIN loss: 0.968
# [Iteration 356/2240] TRAIN loss: 1.053
# [Iteration 361/2240] TRAIN loss: 1.136
# [Iteration 366/2240] TRAIN loss: 1.056
# [Iteration 371/2240] TRAIN loss: 1.060
# [Iteration 376/2240] TRAIN loss: 0.969
# [Iteration 381/2240] TRAIN loss: 1.133
# [Iteration 386/2240] TRAIN loss: 1.233
# [Iteration 391/2240] TRAIN loss: 1.039
# [Epoch 7/40] TRAIN acc/loss: 0.080/1.039
# [Epoch 7/40] VAL   acc/loss: 0.570/1.258
# [Iteration 397/2240] TRAIN loss: 1.044
# [Iteration 402/2240] TRAIN loss: 0.923
# [Iteration 407/2240] TRAIN loss: 1.077
# [Iteration 412/2240] TRAIN loss: 0.974
# [Iteration 417/2240] TRAIN loss: 1.028
# [Iteration 422/2240] TRAIN loss: 1.086
# [Iteration 427/2240] TRAIN loss: 0.949
# [Iteration 432/2240] TRAIN loss: 1.182
# [Iteration 437/2240] TRAIN loss: 1.121
# [Iteration 442/2240] TRAIN loss: 0.739
# [Iteration 447/2240] TRAIN loss: 1.207
# [Epoch 8/40] TRAIN acc/loss: 0.897/1.207
# [Epoch 8/40] VAL   acc/loss: 0.572/1.301
# [Iteration 453/2240] TRAIN loss: 1.174
# [Iteration 458/2240] TRAIN loss: 0.931
# [Iteration 463/2240] TRAIN loss: 0.846
# [Iteration 468/2240] TRAIN loss: 1.120
# [Iteration 473/2240] TRAIN loss: 0.935
# [Iteration 478/2240] TRAIN loss: 1.090
# [Iteration 483/2240] TRAIN loss: 0.984
# [Iteration 488/2240] TRAIN loss: 0.810
# [Iteration 493/2240] TRAIN loss: 1.137
# [Iteration 498/2240] TRAIN loss: 1.051
# [Iteration 503/2240] TRAIN loss: 1.143
# [Epoch 9/40] TRAIN acc/loss: 1.000/1.143
# [Epoch 9/40] VAL   acc/loss: 0.537/1.279
# [Iteration 509/2240] TRAIN loss: 0.929
# [Iteration 514/2240] TRAIN loss: 1.118
# [Iteration 519/2240] TRAIN loss: 1.087
# [Iteration 524/2240] TRAIN loss: 0.947
# [Iteration 529/2240] TRAIN loss: 1.025
# [Iteration 534/2240] TRAIN loss: 0.901
# [Iteration 539/2240] TRAIN loss: 0.861
# [Iteration 544/2240] TRAIN loss: 1.034
# [Iteration 549/2240] TRAIN loss: 1.099
# [Iteration 554/2240] TRAIN loss: 1.071
# [Iteration 559/2240] TRAIN loss: 0.954
# [Epoch 10/40] TRAIN acc/loss: 0.251/0.954
# [Epoch 10/40] VAL   acc/loss: 0.552/1.394
# [Iteration 565/2240] TRAIN loss: 1.109
# [Iteration 570/2240] TRAIN loss: 0.723
# [Iteration 575/2240] TRAIN loss: 0.902
# [Iteration 580/2240] TRAIN loss: 0.961
# [Iteration 585/2240] TRAIN loss: 0.889
# [Iteration 590/2240] TRAIN loss: 1.036
# [Iteration 595/2240] TRAIN loss: 0.887
# [Iteration 600/2240] TRAIN loss: 1.186
# [Iteration 605/2240] TRAIN loss: 0.911
# [Iteration 610/2240] TRAIN loss: 1.138
# [Iteration 615/2240] TRAIN loss: 1.057
# [Epoch 11/40] TRAIN acc/loss: 0.346/1.057
# [Epoch 11/40] VAL   acc/loss: 0.568/1.278
# [Iteration 621/2240] TRAIN loss: 0.783
# [Iteration 626/2240] TRAIN loss: 1.121
# [Iteration 631/2240] TRAIN loss: 0.845
# [Iteration 636/2240] TRAIN loss: 0.887
# [Iteration 641/2240] TRAIN loss: 0.720
# [Iteration 646/2240] TRAIN loss: 1.010
# [Iteration 651/2240] TRAIN loss: 0.958
# [Iteration 656/2240] TRAIN loss: 1.060
# [Iteration 661/2240] TRAIN loss: 1.031
# [Iteration 666/2240] TRAIN loss: 1.053
# [Iteration 671/2240] TRAIN loss: 0.963
# [Epoch 12/40] TRAIN acc/loss: 0.454/0.963
# [Epoch 12/40] VAL   acc/loss: 0.555/1.303
# [Iteration 677/2240] TRAIN loss: 0.829
# [Iteration 682/2240] TRAIN loss: 0.773
# [Iteration 687/2240] TRAIN loss: 0.961
# [Iteration 692/2240] TRAIN loss: 1.001
# [Iteration 697/2240] TRAIN loss: 1.080
# [Iteration 702/2240] TRAIN loss: 0.919
# [Iteration 707/2240] TRAIN loss: 0.973
# [Iteration 712/2240] TRAIN loss: 0.950
# [Iteration 717/2240] TRAIN loss: 1.143
# [Iteration 722/2240] TRAIN loss: 1.030
# [Iteration 727/2240] TRAIN loss: 1.154
# [Epoch 13/40] TRAIN acc/loss: 1.000/1.154
# [Epoch 13/40] VAL   acc/loss: 0.548/1.304
# [Iteration 733/2240] TRAIN loss: 1.021
# [Iteration 738/2240] TRAIN loss: 0.996
# [Iteration 743/2240] TRAIN loss: 1.178
# [Iteration 748/2240] TRAIN loss: 0.918
# [Iteration 753/2240] TRAIN loss: 0.781
# [Iteration 758/2240] TRAIN loss: 0.869
# [Iteration 763/2240] TRAIN loss: 0.914
# [Iteration 768/2240] TRAIN loss: 0.828
# [Iteration 773/2240] TRAIN loss: 0.871
# [Iteration 778/2240] TRAIN loss: 0.788
# [Iteration 783/2240] TRAIN loss: 1.123
# [Epoch 14/40] TRAIN acc/loss: 0.724/1.123
# [Epoch 14/40] VAL   acc/loss: 0.580/1.244
# [Iteration 789/2240] TRAIN loss: 0.767
# [Iteration 794/2240] TRAIN loss: 1.212
# [Iteration 799/2240] TRAIN loss: 1.148
# [Iteration 804/2240] TRAIN loss: 0.590
# [Iteration 809/2240] TRAIN loss: 0.961
# [Iteration 814/2240] TRAIN loss: 1.070
# [Iteration 819/2240] TRAIN loss: 0.853
# [Iteration 824/2240] TRAIN loss: 1.060
# [Iteration 829/2240] TRAIN loss: 1.082
# [Iteration 834/2240] TRAIN loss: 1.017
# [Iteration 839/2240] TRAIN loss: 0.897
# [Epoch 15/40] TRAIN acc/loss: 0.532/0.897
# [Epoch 15/40] VAL   acc/loss: 0.582/1.269
# [Iteration 845/2240] TRAIN loss: 0.917
# [Iteration 850/2240] TRAIN loss: 0.827
# [Iteration 855/2240] TRAIN loss: 0.948
# [Iteration 860/2240] TRAIN loss: 0.851
# [Iteration 865/2240] TRAIN loss: 0.974
# [Iteration 870/2240] TRAIN loss: 0.850
# [Iteration 875/2240] TRAIN loss: 1.121
# [Iteration 880/2240] TRAIN loss: 1.138
# [Iteration 885/2240] TRAIN loss: 1.030
# [Iteration 890/2240] TRAIN loss: 0.901
# [Iteration 895/2240] TRAIN loss: 0.793
# [Epoch 16/40] TRAIN acc/loss: 1.000/0.793
# [Epoch 16/40] VAL   acc/loss: 0.548/1.311
# [Iteration 901/2240] TRAIN loss: 0.899
# [Iteration 906/2240] TRAIN loss: 0.980
# [Iteration 911/2240] TRAIN loss: 0.977
# [Iteration 916/2240] TRAIN loss: 0.865
# [Iteration 921/2240] TRAIN loss: 0.795
# [Iteration 926/2240] TRAIN loss: 0.993
# [Iteration 931/2240] TRAIN loss: 0.927
# [Iteration 936/2240] TRAIN loss: 0.913
# [Iteration 941/2240] TRAIN loss: 0.636
# [Iteration 946/2240] TRAIN loss: 1.060
# [Iteration 951/2240] TRAIN loss: 0.922
# [Epoch 17/40] TRAIN acc/loss: 0.681/0.922
# [Epoch 17/40] VAL   acc/loss: 0.598/1.253
# [Iteration 957/2240] TRAIN loss: 1.025
# [Iteration 962/2240] TRAIN loss: 0.948
# [Iteration 967/2240] TRAIN loss: 0.659
# [Iteration 972/2240] TRAIN loss: 0.961
# [Iteration 977/2240] TRAIN loss: 0.982
# [Iteration 982/2240] TRAIN loss: 0.963
# [Iteration 987/2240] TRAIN loss: 0.930
# [Iteration 992/2240] TRAIN loss: 1.038
# [Iteration 997/2240] TRAIN loss: 0.878
# [Iteration 1002/2240] TRAIN loss: 0.967
# [Iteration 1007/2240] TRAIN loss: 0.818
# [Epoch 18/40] TRAIN acc/loss: 1.000/0.818
# [Epoch 18/40] VAL   acc/loss: 0.566/1.264
# [Iteration 1013/2240] TRAIN loss: 0.894
# [Iteration 1018/2240] TRAIN loss: 1.002
# [Iteration 1023/2240] TRAIN loss: 0.899
# [Iteration 1028/2240] TRAIN loss: 0.765
# [Iteration 1033/2240] TRAIN loss: 1.053
# [Iteration 1038/2240] TRAIN loss: 0.977
# [Iteration 1043/2240] TRAIN loss: 0.811
# [Iteration 1048/2240] TRAIN loss: 0.770
# [Iteration 1053/2240] TRAIN loss: 1.111
# [Iteration 1058/2240] TRAIN loss: 0.935
# [Iteration 1063/2240] TRAIN loss: 0.954
# [Epoch 19/40] TRAIN acc/loss: 1.000/0.954
# [Epoch 19/40] VAL   acc/loss: 0.547/1.283
# [Iteration 1069/2240] TRAIN loss: 1.018
# [Iteration 1074/2240] TRAIN loss: 0.827
# [Iteration 1079/2240] TRAIN loss: 0.955
# [Iteration 1084/2240] TRAIN loss: 0.852
# [Iteration 1089/2240] TRAIN loss: 0.895
# [Iteration 1094/2240] TRAIN loss: 0.734
# [Iteration 1099/2240] TRAIN loss: 0.910
# [Iteration 1104/2240] TRAIN loss: 0.938
# [Iteration 1109/2240] TRAIN loss: 0.955
# [Iteration 1114/2240] TRAIN loss: 0.861
# [Iteration 1119/2240] TRAIN loss: 0.958
# [Epoch 20/40] TRAIN acc/loss: 0.586/0.958
# [Epoch 20/40] VAL   acc/loss: 0.543/1.270
# [Iteration 1125/2240] TRAIN loss: 1.061
# [Iteration 1130/2240] TRAIN loss: 0.726
# [Iteration 1135/2240] TRAIN loss: 0.978
# [Iteration 1140/2240] TRAIN loss: 1.049
# [Iteration 1145/2240] TRAIN loss: 1.131
# [Iteration 1150/2240] TRAIN loss: 0.904
# [Iteration 1155/2240] TRAIN loss: 0.634
# [Iteration 1160/2240] TRAIN loss: 0.745
# [Iteration 1165/2240] TRAIN loss: 1.045
# [Iteration 1170/2240] TRAIN loss: 0.859
# [Iteration 1175/2240] TRAIN loss: 0.733
# [Epoch 21/40] TRAIN acc/loss: 0.333/0.733
# [Epoch 21/40] VAL   acc/loss: 0.557/1.156
# [Iteration 1181/2240] TRAIN loss: 1.046
# [Iteration 1186/2240] TRAIN loss: 0.829
# [Iteration 1191/2240] TRAIN loss: 0.934
# [Iteration 1196/2240] TRAIN loss: 0.809
# [Iteration 1201/2240] TRAIN loss: 0.827
# [Iteration 1206/2240] TRAIN loss: 1.080
# [Iteration 1211/2240] TRAIN loss: 0.866
# [Iteration 1216/2240] TRAIN loss: 0.788
# [Iteration 1221/2240] TRAIN loss: 0.902
# [Iteration 1226/2240] TRAIN loss: 0.924
# [Iteration 1231/2240] TRAIN loss: 0.830
# [Epoch 22/40] TRAIN acc/loss: 0.621/0.830
# [Epoch 22/40] VAL   acc/loss: 0.521/1.251
# [Iteration 1237/2240] TRAIN loss: 0.658
# [Iteration 1242/2240] TRAIN loss: 1.125
# [Iteration 1247/2240] TRAIN loss: 0.796
# [Iteration 1252/2240] TRAIN loss: 0.938
# [Iteration 1257/2240] TRAIN loss: 0.728
# [Iteration 1262/2240] TRAIN loss: 0.899
# [Iteration 1267/2240] TRAIN loss: 1.206
# [Iteration 1272/2240] TRAIN loss: 0.810
# [Iteration 1277/2240] TRAIN loss: 0.672
# [Iteration 1282/2240] TRAIN loss: 1.070
# [Iteration 1287/2240] TRAIN loss: 0.796
# [Epoch 23/40] TRAIN acc/loss: 0.629/0.796
# [Epoch 23/40] VAL   acc/loss: 0.575/1.232
# [Iteration 1293/2240] TRAIN loss: 0.990
# [Iteration 1298/2240] TRAIN loss: 0.792
# [Iteration 1303/2240] TRAIN loss: 0.771
# [Iteration 1308/2240] TRAIN loss: 0.964
# [Iteration 1313/2240] TRAIN loss: 0.956
# [Iteration 1318/2240] TRAIN loss: 0.960
# [Iteration 1323/2240] TRAIN loss: 0.853
# [Iteration 1328/2240] TRAIN loss: 0.913
# [Iteration 1333/2240] TRAIN loss: 0.984
# [Iteration 1338/2240] TRAIN loss: 0.920
# [Iteration 1343/2240] TRAIN loss: 0.826
# [Epoch 24/40] TRAIN acc/loss: 0.562/0.826
# [Epoch 24/40] VAL   acc/loss: 0.546/1.267
# [Iteration 1349/2240] TRAIN loss: 0.978
# [Iteration 1354/2240] TRAIN loss: 0.837
# [Iteration 1359/2240] TRAIN loss: 0.915
# [Iteration 1364/2240] TRAIN loss: 0.921
# [Iteration 1369/2240] TRAIN loss: 0.770
# [Iteration 1374/2240] TRAIN loss: 0.721
# [Iteration 1379/2240] TRAIN loss: 0.800
# [Iteration 1384/2240] TRAIN loss: 1.076
# [Iteration 1389/2240] TRAIN loss: 0.896
# [Iteration 1394/2240] TRAIN loss: 0.792
# [Iteration 1399/2240] TRAIN loss: 0.806
# [Epoch 25/40] TRAIN acc/loss: 1.000/0.806
# [Epoch 25/40] VAL   acc/loss: 0.596/1.201
# [Iteration 1405/2240] TRAIN loss: 0.802
# [Iteration 1410/2240] TRAIN loss: 1.009
# [Iteration 1415/2240] TRAIN loss: 0.856
# [Iteration 1420/2240] TRAIN loss: 0.912
# [Iteration 1425/2240] TRAIN loss: 0.878
# [Iteration 1430/2240] TRAIN loss: 0.930
# [Iteration 1435/2240] TRAIN loss: 0.835
# [Iteration 1440/2240] TRAIN loss: 0.723
# [Iteration 1445/2240] TRAIN loss: 1.010
# [Iteration 1450/2240] TRAIN loss: 0.978
# [Iteration 1455/2240] TRAIN loss: 0.663
# [Epoch 26/40] TRAIN acc/loss: 0.905/0.663
# [Epoch 26/40] VAL   acc/loss: 0.530/1.265
# [Iteration 1461/2240] TRAIN loss: 0.880
# [Iteration 1466/2240] TRAIN loss: 0.984
# [Iteration 1471/2240] TRAIN loss: 0.858
# [Iteration 1476/2240] TRAIN loss: 0.909
# [Iteration 1481/2240] TRAIN loss: 0.634
# [Iteration 1486/2240] TRAIN loss: 0.976
# [Iteration 1491/2240] TRAIN loss: 0.793
# [Iteration 1496/2240] TRAIN loss: 0.987
# [Iteration 1501/2240] TRAIN loss: 0.928
# [Iteration 1506/2240] TRAIN loss: 0.923
# [Iteration 1511/2240] TRAIN loss: 0.739
# [Epoch 27/40] TRAIN acc/loss: 1.000/0.739
# [Epoch 27/40] VAL   acc/loss: 0.527/1.212
# [Iteration 1517/2240] TRAIN loss: 0.874
# [Iteration 1522/2240] TRAIN loss: 0.951
# [Iteration 1527/2240] TRAIN loss: 0.798
# [Iteration 1532/2240] TRAIN loss: 1.024
# [Iteration 1537/2240] TRAIN loss: 0.905
# [Iteration 1542/2240] TRAIN loss: 0.880
# [Iteration 1547/2240] TRAIN loss: 0.862
# [Iteration 1552/2240] TRAIN loss: 0.711
# [Iteration 1557/2240] TRAIN loss: 0.788
# [Iteration 1562/2240] TRAIN loss: 1.061
# [Iteration 1567/2240] TRAIN loss: 0.811
# [Epoch 28/40] TRAIN acc/loss: 0.608/0.811
# [Epoch 28/40] VAL   acc/loss: 0.540/1.255
# [Iteration 1573/2240] TRAIN loss: 0.677
# [Iteration 1578/2240] TRAIN loss: 1.000
# [Iteration 1583/2240] TRAIN loss: 0.830
# [Iteration 1588/2240] TRAIN loss: 0.804
# [Iteration 1593/2240] TRAIN loss: 0.862
# [Iteration 1598/2240] TRAIN loss: 0.847
# [Iteration 1603/2240] TRAIN loss: 0.787
# [Iteration 1608/2240] TRAIN loss: 0.785
# [Iteration 1613/2240] TRAIN loss: 0.901
# [Iteration 1618/2240] TRAIN loss: 1.100
# [Iteration 1623/2240] TRAIN loss: 0.877
# [Epoch 29/40] TRAIN acc/loss: 0.804/0.877
# [Epoch 29/40] VAL   acc/loss: 0.547/1.286
# [Iteration 1629/2240] TRAIN loss: 1.034
# [Iteration 1634/2240] TRAIN loss: 0.987
# [Iteration 1639/2240] TRAIN loss: 0.929
# [Iteration 1644/2240] TRAIN loss: 0.864
# [Iteration 1649/2240] TRAIN loss: 0.668
# [Iteration 1654/2240] TRAIN loss: 0.768
# [Iteration 1659/2240] TRAIN loss: 0.831
# [Iteration 1664/2240] TRAIN loss: 0.943
# [Iteration 1669/2240] TRAIN loss: 0.911
# [Iteration 1674/2240] TRAIN loss: 0.771
# [Iteration 1679/2240] TRAIN loss: 0.811
# [Epoch 30/40] TRAIN acc/loss: 0.456/0.811
# [Epoch 30/40] VAL   acc/loss: 0.549/1.272
# [Iteration 1685/2240] TRAIN loss: 0.779
# [Iteration 1690/2240] TRAIN loss: 0.660
# [Iteration 1695/2240] TRAIN loss: 0.815
# [Iteration 1700/2240] TRAIN loss: 0.931
# [Iteration 1705/2240] TRAIN loss: 0.955
# [Iteration 1710/2240] TRAIN loss: 0.957
# [Iteration 1715/2240] TRAIN loss: 1.053
# [Iteration 1720/2240] TRAIN loss: 0.898
# [Iteration 1725/2240] TRAIN loss: 0.777
# [Iteration 1730/2240] TRAIN loss: 0.871
# [Iteration 1735/2240] TRAIN loss: 0.878
# [Epoch 31/40] TRAIN acc/loss: 0.421/0.878
# [Epoch 31/40] VAL   acc/loss: 0.579/1.214
# [Iteration 1741/2240] TRAIN loss: 0.953
# [Iteration 1746/2240] TRAIN loss: 0.911
# [Iteration 1751/2240] TRAIN loss: 0.988
# [Iteration 1756/2240] TRAIN loss: 0.910
# [Iteration 1761/2240] TRAIN loss: 0.981
# [Iteration 1766/2240] TRAIN loss: 0.938
# [Iteration 1771/2240] TRAIN loss: 0.782
# [Iteration 1776/2240] TRAIN loss: 0.730
# [Iteration 1781/2240] TRAIN loss: 0.792
# [Iteration 1786/2240] TRAIN loss: 0.633
# [Iteration 1791/2240] TRAIN loss: 0.684
# [Epoch 32/40] TRAIN acc/loss: 1.000/0.684
# [Epoch 32/40] VAL   acc/loss: 0.579/1.199
# [Iteration 1797/2240] TRAIN loss: 0.930
# [Iteration 1802/2240] TRAIN loss: 0.783
# [Iteration 1807/2240] TRAIN loss: 1.045
# [Iteration 1812/2240] TRAIN loss: 0.887
# [Iteration 1817/2240] TRAIN loss: 0.792
# [Iteration 1822/2240] TRAIN loss: 0.925
# [Iteration 1827/2240] TRAIN loss: 0.896
# [Iteration 1832/2240] TRAIN loss: 0.724
# [Iteration 1837/2240] TRAIN loss: 0.800
# [Iteration 1842/2240] TRAIN loss: 0.745
# [Iteration 1847/2240] TRAIN loss: 0.817
# [Epoch 33/40] TRAIN acc/loss: 0.457/0.817
# [Epoch 33/40] VAL   acc/loss: 0.567/1.230
# [Iteration 1853/2240] TRAIN loss: 0.989
# [Iteration 1858/2240] TRAIN loss: 0.926
# [Iteration 1863/2240] TRAIN loss: 0.832
# [Iteration 1868/2240] TRAIN loss: 0.845
# [Iteration 1873/2240] TRAIN loss: 0.787
# [Iteration 1878/2240] TRAIN loss: 0.882
# [Iteration 1883/2240] TRAIN loss: 0.882
# [Iteration 1888/2240] TRAIN loss: 0.925
# [Iteration 1893/2240] TRAIN loss: 0.774
# [Iteration 1898/2240] TRAIN loss: 0.962
# [Iteration 1903/2240] TRAIN loss: 0.808
# [Epoch 34/40] TRAIN acc/loss: 0.344/0.808
# [Epoch 34/40] VAL   acc/loss: 0.546/1.249
# [Iteration 1909/2240] TRAIN loss: 0.713
# [Iteration 1914/2240] TRAIN loss: 0.850
# [Iteration 1919/2240] TRAIN loss: 0.984
# [Iteration 1924/2240] TRAIN loss: 0.824
# [Iteration 1929/2240] TRAIN loss: 0.818
# [Iteration 1934/2240] TRAIN loss: 0.761
# [Iteration 1939/2240] TRAIN loss: 0.828
# [Iteration 1944/2240] TRAIN loss: 0.929
# [Iteration 1949/2240] TRAIN loss: 0.961
# [Iteration 1954/2240] TRAIN loss: 0.907
# [Iteration 1959/2240] TRAIN loss: 0.826
# [Epoch 35/40] TRAIN acc/loss: 0.582/0.826
# [Epoch 35/40] VAL   acc/loss: 0.552/1.240
# [Iteration 1965/2240] TRAIN loss: 0.904
# [Iteration 1970/2240] TRAIN loss: 0.852
# [Iteration 1975/2240] TRAIN loss: 0.721
# [Iteration 1980/2240] TRAIN loss: 0.985
# [Iteration 1985/2240] TRAIN loss: 0.790
# [Iteration 1990/2240] TRAIN loss: 0.971
# [Iteration 1995/2240] TRAIN loss: 0.886
# [Iteration 2000/2240] TRAIN loss: 0.797
# [Iteration 2005/2240] TRAIN loss: 0.759
# [Iteration 2010/2240] TRAIN loss: 0.816
# [Iteration 2015/2240] TRAIN loss: 0.891
# [Epoch 36/40] TRAIN acc/loss: 1.000/0.891
# [Epoch 36/40] VAL   acc/loss: 0.545/1.221
# [Iteration 2021/2240] TRAIN loss: 0.858
# [Iteration 2026/2240] TRAIN loss: 0.994
# [Iteration 2031/2240] TRAIN loss: 0.817
# [Iteration 2036/2240] TRAIN loss: 1.059
# [Iteration 2041/2240] TRAIN loss: 0.891
# [Iteration 2046/2240] TRAIN loss: 0.853
# [Iteration 2051/2240] TRAIN loss: 0.803
# [Iteration 2056/2240] TRAIN loss: 0.794
# [Iteration 2061/2240] TRAIN loss: 0.816
# [Iteration 2066/2240] TRAIN loss: 0.825
# [Iteration 2071/2240] TRAIN loss: 0.771
# [Epoch 37/40] TRAIN acc/loss: 1.000/0.771
# [Epoch 37/40] VAL   acc/loss: 0.572/1.229
# [Iteration 2077/2240] TRAIN loss: 0.915
# [Iteration 2082/2240] TRAIN loss: 0.815
# [Iteration 2087/2240] TRAIN loss: 0.885
# [Iteration 2092/2240] TRAIN loss: 0.996
# [Iteration 2097/2240] TRAIN loss: 0.935
# [Iteration 2102/2240] TRAIN loss: 0.923
# [Iteration 2107/2240] TRAIN loss: 0.707
# [Iteration 2112/2240] TRAIN loss: 0.695
# [Iteration 2117/2240] TRAIN loss: 0.925
# [Iteration 2122/2240] TRAIN loss: 0.675
# [Iteration 2127/2240] TRAIN loss: 0.848
# [Epoch 38/40] TRAIN acc/loss: 0.431/0.848
# [Epoch 38/40] VAL   acc/loss: 0.539/1.276
# [Iteration 2133/2240] TRAIN loss: 0.872
# [Iteration 2138/2240] TRAIN loss: 1.090
# [Iteration 2143/2240] TRAIN loss: 0.996
# [Iteration 2148/2240] TRAIN loss: 0.828
# [Iteration 2153/2240] TRAIN loss: 0.648
# [Iteration 2158/2240] TRAIN loss: 0.848
# [Iteration 2163/2240] TRAIN loss: 1.060
# [Iteration 2168/2240] TRAIN loss: 0.811
# [Iteration 2173/2240] TRAIN loss: 0.871
# [Iteration 2178/2240] TRAIN loss: 0.715
# [Iteration 2183/2240] TRAIN loss: 0.674
# [Epoch 39/40] TRAIN acc/loss: 0.507/0.674
# [Epoch 39/40] VAL   acc/loss: 0.558/1.255
# [Iteration 2189/2240] TRAIN loss: 0.941
# [Iteration 2194/2240] TRAIN loss: 0.881
# [Iteration 2199/2240] TRAIN loss: 1.053
# [Iteration 2204/2240] TRAIN loss: 0.790
# [Iteration 2209/2240] TRAIN loss: 0.914
# [Iteration 2214/2240] TRAIN loss: 0.946
# [Iteration 2219/2240] TRAIN loss: 0.889
# [Iteration 2224/2240] TRAIN loss: 0.789
# [Iteration 2229/2240] TRAIN loss: 0.776
# [Iteration 2234/2240] TRAIN loss: 0.753
# [Iteration 2239/2240] TRAIN loss: 0.728
# [Epoch 40/40] TRAIN acc/loss: 0.718/0.728
# [Epoch 40/40] VAL   acc/loss: 0.543/1.295
# FINISH.

# %% [markdown]
# # Test your Model

# %%
test_data = SegmentationData(image_paths_file='datasets/segmentation_data_test/test.txt')
test_loader = torch.utils.data.DataLoader(test_data,
                                          batch_size=1,
                                          shuffle=False,
                                          num_workers=1)

test_scores = []
model.eval()
for inputs, targets in test_loader:
    inputs, targets = inputs.to(device), targets.to(device)
    
    outputs = model.forward(inputs)
    _, preds = torch.max(outputs, 1)
    targets_mask = targets >= 0
    test_scores.append(np.mean((preds == targets)[targets_mask].data.cpu().numpy()))
    
model.train()
np.mean(test_scores)
# Out:
# 0.6238267678453401

# %% [markdown]
# # Visualization

# %%
num_example_imgs = 4
plt.figure(figsize=(15, 5 * num_example_imgs))
for i, (img, target) in enumerate(test_data[:num_example_imgs]):
    inputs = img.unsqueeze(0)
    inputs = inputs.to(device)
    
    outputs = model.forward(inputs)
    _, preds = torch.max(outputs, 1)
    pred = preds[0].data.cpu()
    
    img, target, pred = img.numpy(), target.numpy(), pred.numpy()
    
    # img
    plt.subplot(num_example_imgs, 3, i * 3 + 1)
    plt.axis('off')
    plt.imshow(img.transpose(1,2,0))
    if i == 0:
        plt.title("Input image")
    
    # target
    plt.subplot(num_example_imgs, 3, i * 3 + 2)
    plt.axis('off')
    plt.imshow(label_img_to_rgb(target))
    if i == 0:
        plt.title("Target image")

    # pred
    plt.subplot(num_example_imgs, 3, i * 3 + 3)
    plt.axis('off')
    plt.imshow(label_img_to_rgb(pred))
    if i == 0:
        plt.title("Prediction image")
    
plt.show()

# %% [markdown]
# ## Visualize Filter Weights
# You can visualize the convolutional filters of the very first layer by running the following cell. The kernels should exhibit clear structures of differently oriented edges, corners and circles.

# %%
from exercise_code.vis_utils import visualize_grid

# first (next) parameter should be convolutional
conv_params = next(model.parameters()).data.cpu().numpy()
grid = visualize_grid(conv_params.transpose(0, 2, 3, 1))
plt.imshow(grid.astype('uint8'))
plt.axis('off')
plt.gcf().set_size_inches(6, 6)
plt.show()

# %% [markdown]
# ## Save the Model and Submission
#
# When you are satisfied with your training, save the model for submission. In order to be eligible for the bonus points you have to achieve an accuracy above __60%__.

# %%
model.save("models/segmentation_nn.model")
# Out:
# Saving model... models/segmentation_nn.model

# %% [markdown]
# ## Possible Next Steps
#
# 1. Implement and integrate a task specific metric such as [Intersection over Union (IoU)](http://www.pyimagesearch.com/2016/11/07/intersection-over-union-iou-for-object-detection/)
# 2. Hyperparameter optimization
# 3. Data augmentation ([PyTorch tutorial](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html))
